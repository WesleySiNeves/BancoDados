-- %% [markdown]
-- # Script que altera a senha do cliente

-- %%
DECLARE @ClienteAntigo VARCHAR(30);
DECLARE @senha1 VARCHAR(200) = '$2a$12$lbLe8w5BgfjU9zxomOdkwelPAv8/DHzft1QXM7D4MwbueGYm7l2cm';
DECLARE @IdUsuario UNIQUEIDENTIFIER = '681DADD3-ACA0-48DB-A8EC-0E740FE79422';
DECLARE @SenhaAintiga VARCHAR(200) = '';
DECLARE @EmailPadrao VARCHAR(100) = 'teste@teste';

 

DECLARE @NomeUsuarioPadraoImplanta VARCHAR(100) = 'Implanta';

 


 SELECT * FROM Acesso.Usuarios U

 WHERE U.IdUsuario =@IdUsuario


UPDATE Acesso.Usuarios
SET SenhaHash = @senha1,
SenhaTipoHash='SHA512',
SenhaAlgoritmo='bcrypt'
WHERE Usuarios.IdUsuario =@IdUsuario
-- Out:
-- (1 row affected)
-- (1 row affected)
-- Total execution time: 00:00:00.050
-- <table><tr><th>IdUsuario</th><th>Usuario</th><th>SenhaHash</th><th>SenhaTipoHash</th><th>SenhaAlgoritmo</th><th>Observacao</th><th>Ativo</th><th>DataValidaSenha</th><th>IdPessoa</th><th>AdministradorLogon</th><th>EmailLogon</th><th>SenhaEsquecida</th><th>IdCargo</th><th>TentativasInvalidasLoginBloqueado</th><th>TentativasInvalidasLoginQuantidade</th><th>Temporario</th><th>DataInicioAcessoTemporario</th><th>DataTerminoAcessoTemporario</th></tr><tr><td>681dadd3-aca0-48db-a8ec-0e740fe79422</td><td>CRQAM</td><td>$2a$12$lbLe8w5BgfjU9zxomOdkwelPAv8/DHzft1QXM7D4MwbueGYm7l2cm</td><td>SHA512</td><td>bcrypt</td><td></td><td>1</td><td>2060-12-30</td><td>681dadd3-aca0-48db-a8ec-0e740fe79422</td><td>1</td><td>implanta30@implantainfo.com.br</td><td>0</td><td>00000000-0000-0000-0000-000000000000</td><td>0</td><td>0</td><td>0</td><td>NULL</td><td>NULL</td></tr></table>
