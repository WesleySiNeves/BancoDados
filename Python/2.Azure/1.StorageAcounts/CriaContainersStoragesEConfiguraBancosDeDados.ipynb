# %% [markdown]
# # importação de backups

# %%
import pyodbc as PDB  # Drive para conexão com banco de dados
import pandas  as pd
import sys
import os
import traceback
import json
import re

# %%
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient, __version__

# %%
print("Azure Blob Storage v" + __version__ + " - Python quickstart sample")
# Out:
# Azure Blob Storage v12.8.0 - Python quickstart sample

# %% [markdown]
# ## Importa o arquivo com as configurações

# %%
datasource = pd.read_excel(r'D:\Ondrive\OneDrive - Implanta Informatica\Migração arquivos Anexos\ClientesComESemComfiguracaoArquivosAnexos.xlsx',sheet_name='registros')

# %%
datasource.reset_index()
# Out:
#      index                 Cliente Categoria   object_id Nome Schema  \
# 0        0  cau-ac.implanta.net.br       cau    62479847     Sistema
# 1        1  cau-al.implanta.net.br       cau  2086766987     Sistema
# 2        2  cau-am.implanta.net.br       cau  1115007599     Sistema
# 3        3  cau-ap.implanta.net.br       cau   378484427     Sistema
# 4        4  cau-ba.implanta.net.br       cau   378484427     Sistema
# ..     ...                     ...       ...         ...         ...
# 380    380  oab-pi.implanta.net.br       oab   538484997     Sistema
# 381    381  oab-rn.implanta.net.br       oab   538484997     Sistema
# 382    382  oab-rr.implanta.net.br       oab   538484997     Sistema
# 383    383  oab-rs.implanta.net.br       oab  1190672431     Sistema
# 384    384  oab-se.implanta.net.br       oab   538484997     Sistema
#
#         Nome Tabela  Bytes/Row Quantidade Registros  MigracaoDiaria  \
# 0    ArquivosAnexos     5410.0                3.699             500
# 1    ArquivosAnexos   211995.0                2.936             500
# 2    ArquivosAnexos   240190.0                3.799             500
# 3    ArquivosAnexos   191347.0                4.018             500
# 4    ArquivosAnexos   401356.0                1.284             500
# ..              ...        ...                  ...             ...
# 380  ArquivosAnexos   116593.0                   43             500
# 381  ArquivosAnexos  1378183.0                   17             500
# 382  ArquivosAnexos   147456.0                    2             500
# 383  ArquivosAnexos   219649.0               65.016             500
# 384  ArquivosAnexos   174834.0                  152             500
#
#      QuantideDias  ...  TotalMB  Total MB Por Schema  TotalAlocadoMB  \
# 0               1  ...     19.0                 19.0        19.00 MB
# 1               6  ...    593.0                593.0       593.00 MB
# 2               8  ...    870.0                870.0       870.00 MB
# 3               9  ...    733.0                733.0       733.00 MB
# 4               3  ...    491.0                491.0       491.00 MB
# ..            ...  ...      ...                  ...             ...
# 380             1  ...      4.0                  4.0         4.00 MB
# 381             1  ...     22.0                 22.0        22.00 MB
# 382             1  ...      0.0                  0.0         0.00 MB
# 383           131  ...  13619.0              13619.0     13619.00 MB
# 384             1  ...     25.0                 25.0        25.00 MB
#
#      TotalUsadoMB UtilizaAzure StorageAccount  \
# 0           17 MB          SIM    improblob01
# 1          588 MB          NAO    improblob01
# 2          863 MB          NAO    improblob01
# 3          731 MB          NAO    improblob01
# 4          489 MB          NAO    improblob01
# ..            ...          ...            ...
# 380          4 MB          NAO    improblob03
# 381         22 MB          NAO    improblob03
# 382          0 MB          NAO    improblob03
# 383      13602 MB          NAO    improblob03
# 384         25 MB          NAO    improblob03
#
#     ContainerAzureStorageArquivosAnexos  \
# 0                                cau-ac
# 1                                cau-al
# 2                                cau-am
# 3                                cau-ap
# 4                                cau-ba
# ..                                  ...
# 380                              oab-pi
# 381                              oab-rn
# 382                              oab-rr
# 383                              oab-rs
# 384                              oab-se
#
#     CaminhoCacheLocalAzureStorageArquivosAnexos  \
# 0                    D:\temp_blob_azure\cau-ac\
# 1                    D:\temp_blob_azure\cau-al\
# 2                    D:\temp_blob_azure\cau-am\
# 3                    D:\temp_blob_azure\cau-ap\
# 4                    D:\temp_blob_azure\cau-ba\
# ..                                          ...
# 380                  D:\temp_blob_azure\oab-pi\
# 381                  D:\temp_blob_azure\oab-rn\
# 382                  D:\temp_blob_azure\oab-rr\
# 383                  D:\temp_blob_azure\oab-rs\
# 384                  D:\temp_blob_azure\oab-se\
#
#             ConnectionStringAzureStorageArquivosAnexos  \
# 0    DefaultEndpointsProtocol=https;AccountName=imp...
# 1    DefaultEndpointsProtocol=https;AccountName=imp...
# 2    DefaultEndpointsProtocol=https;AccountName=imp...
# 3    DefaultEndpointsProtocol=https;AccountName=imp...
# 4    DefaultEndpointsProtocol=https;AccountName=imp...
# ..                                                 ...
# 380  DefaultEndpointsProtocol=https;AccountName=imp...
# 381  DefaultEndpointsProtocol=https;AccountName=imp...
# 382  DefaultEndpointsProtocol=https;AccountName=imp...
# 383  DefaultEndpointsProtocol=https;AccountName=imp...
# 384  DefaultEndpointsProtocol=https;AccountName=imp...
#
#     HorarioMigracaoArquivosAnexosParaAzureStorage
# 0                                        23:00:00
# 1                                        23:00:00
# 2                                        21:00:00
# 3                                        23:00:00
# 4                                        22:00:00
# ..                                            ...
# 380                                      02:00:00
# 381                                      03:00:00
# 382                                      23:00:00
# 383                                      02:00:00
# 384                                      01:00:00
#
# [385 rows x 22 columns]

# %% [markdown]
# ## Planilha com as configuracoes dos bancos de dados

# %%
datasource[0:1]
# Out:
#                   Cliente Categoria  object_id Nome Schema     Nome Tabela  \
# 0  cau-ac.implanta.net.br       cau   62479847     Sistema  ArquivosAnexos
#
#    Bytes/Row Quantidade Registros  MigracaoDiaria  QuantideDias  \
# 0     5410.0                3.699             500             1
#
#   (No column name)  ...  TotalMB  Total MB Por Schema  TotalAlocadoMB  \
# 0              ==>  ...     19.0                 19.0        19.00 MB
#
#   TotalUsadoMB UtilizaAzure StorageAccount  \
# 0        17 MB          SIM    improblob01
#
#   ContainerAzureStorageArquivosAnexos  \
# 0                              cau-ac
#
#   CaminhoCacheLocalAzureStorageArquivosAnexos  \
# 0                  D:\temp_blob_azure\cau-ac\
#
#           ConnectionStringAzureStorageArquivosAnexos  \
# 0  DefaultEndpointsProtocol=https;AccountName=imp...
#
#   HorarioMigracaoArquivosAnexosParaAzureStorage
# 0                                      23:00:00
#
# [1 rows x 21 columns]

# %% [markdown]
# # Cria se necessários todos os containes no azure
# improblob01

# %%
for index , row in datasource.iterrows():
    database = row["Cliente"]
    categoria = row["Categoria"]
    migracaoDiaria = row["MigracaoDiaria"]
    totalArquivosNoBanco = row["TotalArquivosNoBanco"]
    UtilizaAzure = row["UtilizaAzure"]
    storageAccount =  row["StorageAccount"]
    container =row["ContainerAzureStorageArquivosAnexos"]
    horarioMigracao =row["HorarioMigracaoArquivosAnexosParaAzureStorage"]
    connect_str_to_storage = row["ConnectionStringAzureStorageArquivosAnexos"]

    blob_service_client = BlobServiceClient.from_connection_string(connect_str_to_storage)

    existContainer = blob_service_client.get_container_client(container).exists()

    
    if(existContainer ==False):
        blob_service_client.create_container(container)
        print('database:',database,' storageAccount:',storageAccount,' Container Criado',container)
    else:
         print('database:',database,' storageAccount:',storageAccount,' Container já existe',container)
# Out:
# database: cau-ac.implanta.net.br  storageAccount: improblob01  Container já existe cau-ac
# database: cau-al.implanta.net.br  storageAccount: improblob01  Container já existe cau-al
# database: cau-am.implanta.net.br  storageAccount: improblob01  Container já existe cau-am
# database: cau-ap.implanta.net.br  storageAccount: improblob01  Container já existe cau-ap
# database: cau-ba.implanta.net.br  storageAccount: improblob01  Container já existe cau-ba
# database: cau-br.implanta.net.br  storageAccount: improblob01  Container já existe cau-br
# database: cau-ce.implanta.net.br  storageAccount: improblob01  Container já existe cau-ce
# database: cau-df.implanta.net.br  storageAccount: improblob01  Container já existe cau-df
# database: cau-es.implanta.net.br  storageAccount: improblob01  Container já existe cau-es
# database: cau-go.implanta.net.br  storageAccount: improblob01  Container já existe cau-go
# database: cau-ma.implanta.net.br  storageAccount: improblob01  Container já existe cau-ma
# database: cau-mg.implanta.net.br  storageAccount: improblob01  Container já existe cau-mg
# database: cau-ms.implanta.net.br  storageAccount: improblob01  Container já existe cau-ms
# database: cau-mt.implanta.net.br  storageAccount: improblob01  Container já existe cau-mt
# database: cau-pa.implanta.net.br  storageAccount: improblob01  Container já existe cau-pa
# database: cau-pb.implanta.net.br  storageAccount: improblob01  Container já existe cau-pb
# database: cau-pe.implanta.net.br  storageAccount: improblob01  Container já existe cau-pe
# database: cau-pi.implanta.net.br  storageAccount: improblob01  Container já existe cau-pi
# database: cau-pr.implanta.net.br  storageAccount: improblob01  Container já existe cau-pr
# database: cau-rj.implanta.net.br  storageAccount: improblob01  Container já existe cau-rj
# database: cau-rn.implanta.net.br  storageAccount: improblob01  Container já existe cau-rn
# database: cau-ro.implanta.net.br  storageAccount: improblob01  Container já existe cau-ro
# database: cau-rr.implanta.net.br  storageAccount: improblob01  Container já existe cau-rr
# database: cau-rs.implanta.net.br  storageAccount: improblob01  Container já existe cau-rs
# database: cau-sc.implanta.net.br  storageAccount: improblob01  Container já existe cau-sc
# database: cau-se.implanta.net.br  storageAccount: improblob01  Container já existe cau-se
# database: cau-sp.implanta.net.br  storageAccount: improblob01  Container já existe cau-sp
# database: cau-to.implanta.net.br  storageAccount: improblob01  Container já existe cau-to
# database: cfa-br.implanta.net.br  storageAccount: improblob01  Container já existe cfa-br
# database: cra-ac.implanta.net.br  storageAccount: improblob01  Container já existe cra-ac
# database: cra-al.implanta.net.br  storageAccount: improblob01  Container já existe cra-al
# database: cra-am.implanta.net.br  storageAccount: improblob01  Container já existe cra-am
# database: cra-ap.implanta.net.br  storageAccount: improblob01  Container já existe cra-ap
# database: cra-es.implanta.net.br  storageAccount: improblob01  Container já existe cra-es
# database: cra-ma.implanta.net.br  storageAccount: improblob01  Container já existe cra-ma
# database: cra-ms.implanta.net.br  storageAccount: improblob01  Container já existe cra-ms
# database: cra-mt.implanta.net.br  storageAccount: improblob01  Container já existe cra-mt
# database: cra-pa.implanta.net.br  storageAccount: improblob01  Container já existe cra-pa
# database: cra-pb.implanta.net.br  storageAccount: improblob01  Container já existe cra-pb
# database: cra-pe.implanta.net.br  storageAccount: improblob01  Container já existe cra-pe
# database: cra-pi.implanta.net.br  storageAccount: improblob01  Container já existe cra-pi
# database: cra-pr.implanta.net.br  storageAccount: improblob01  Container já existe cra-pr
# database: cra-rn.implanta.net.br  storageAccount: improblob01  Container já existe cra-rn
# database: cra-ro.implanta.net.br  storageAccount: improblob01  Container já existe cra-ro
# database: cra-rr.implanta.net.br  storageAccount: improblob01  Container já existe cra-rr
# database: cra-rs.implanta.net.br  storageAccount: improblob01  Container já existe cra-rs
# database: cra-sc.implanta.net.br  storageAccount: improblob01  Container já existe cra-sc
# database: cra-se.implanta.net.br  storageAccount: improblob01  Container já existe cra-se
# database: cra-sp.implanta.net.br  storageAccount: improblob01  Container já existe cra-sp
# database: cra-to.implanta.net.br  storageAccount: improblob01  Container já existe cra-to
# database: crbm-01.implanta.net.br  storageAccount: improblob01  Container já existe crbm-01
# database: crbm-04.implanta.net.br  storageAccount: improblob01  Container já existe crbm-04
# database: cro-ac.implanta.net.br  storageAccount: improblob01  Container já existe cro-ac
# database: cro-al.implanta.net.br  storageAccount: improblob01  Container já existe cro-al
# database: cro-am.implanta.net.br  storageAccount: improblob01  Container já existe cro-am
# database: cro-ap.implanta.net.br  storageAccount: improblob01  Container já existe cro-ap
# database: cro-ba.implanta.net.br  storageAccount: improblob01  Container já existe cro-ba
# database: cro-ce.implanta.net.br  storageAccount: improblob01  Container já existe cro-ce
# database: cro-df.implanta.net.br  storageAccount: improblob01  Container já existe cro-df
# database: cro-es.implanta.net.br  storageAccount: improblob01  Container já existe cro-es
# database: cro-ma.implanta.net.br  storageAccount: improblob01  Container já existe cro-ma
# database: cro-mg.implanta.net.br  storageAccount: improblob01  Container já existe cro-mg
# database: cro-ms.implanta.net.br  storageAccount: improblob01  Container já existe cro-ms
# database: cro-mt.implanta.net.br  storageAccount: improblob01  Container já existe cro-mt
# database: cro-pa.implanta.net.br  storageAccount: improblob01  Container já existe cro-pa
# database: cro-pb.implanta.net.br  storageAccount: improblob01  Container já existe cro-pb
# database: cro-pe.implanta.net.br  storageAccount: improblob01  Container já existe cro-pe
# database: cro-pi.implanta.net.br  storageAccount: improblob01  Container já existe cro-pi
# database: cro-pr.implanta.net.br  storageAccount: improblob01  Container já existe cro-pr
# database: cro-rj.implanta.net.br  storageAccount: improblob01  Container já existe cro-rj
# database: cro-rn.implanta.net.br  storageAccount: improblob01  Container já existe cro-rn
# database: cro-ro.implanta.net.br  storageAccount: improblob01  Container já existe cro-ro
# database: cro-rr.implanta.net.br  storageAccount: improblob01  Container já existe cro-rr
# database: cro-rs.implanta.net.br  storageAccount: improblob01  Container já existe cro-rs
# database: cro-sc.implanta.net.br  storageAccount: improblob01  Container já existe cro-sc
# database: cro-se.implanta.net.br  storageAccount: improblob01  Container já existe cro-se
# database: cro-to.implanta.net.br  storageAccount: improblob01  Container já existe cro-to
# database: crq-am.implanta.net.br  storageAccount: improblob01  Container já existe crq-am
# database: crq-ba.implanta.net.br  storageAccount: improblob01  Container já existe crq-ba
# database: crq-ce.implanta.net.br  storageAccount: improblob01  Container já existe crq-ce
# database: crq-es.implanta.net.br  storageAccount: improblob01  Container já existe crq-es
# database: crq-go.implanta.net.br  storageAccount: improblob01  Container já existe crq-go
# database: crq-ma.implanta.net.br  storageAccount: improblob01  Container já existe crq-ma
# database: crq-ms.implanta.net.br  storageAccount: improblob01  Container já existe crq-ms
# database: crq-mt.implanta.net.br  storageAccount: improblob01  Container já existe crq-mt
# database: crq-pa.implanta.net.br  storageAccount: improblob01  Container já existe crq-pa
# database: crq-pb.implanta.net.br  storageAccount: improblob01  Container já existe crq-pb
# database: crq-pe.implanta.net.br  storageAccount: improblob01  Container já existe crq-pe
# database: crq-pi.implanta.net.br  storageAccount: improblob01  Container já existe crq-pi
# database: crq-pr.implanta.net.br  storageAccount: improblob01  Container já existe crq-pr
# database: crq-rj.implanta.net.br  storageAccount: improblob01  Container já existe crq-rj
# database: crq-rn.implanta.net.br  storageAccount: improblob01  Container já existe crq-rn
# database: crq-rs.implanta.net.br  storageAccount: improblob01  Container já existe crq-rs
# database: crq-sc.implanta.net.br  storageAccount: improblob01  Container já existe crq-sc
# database: crq-se.implanta.net.br  storageAccount: improblob01  Container já existe crq-se
# database: crq-sp.implanta.net.br  storageAccount: improblob01  Container já existe crq-sp
# database: crt-01.implanta.net.br  storageAccount: improblob01  Container já existe crt-01
# database: crt-02.implanta.net.br  storageAccount: improblob01  Container já existe crt-02
# database: crt-03.implanta.net.br  storageAccount: improblob01  Container já existe crt-03
# database: crt-04.implanta.net.br  storageAccount: improblob01  Container já existe crt-04
# database: crt-ba.implanta.net.br  storageAccount: improblob01  Container já existe crt-ba
# database: crt-es.implanta.net.br  storageAccount: improblob01  Container já existe crt-es
# database: crt-mg.implanta.net.br  storageAccount: improblob01  Container já existe crt-mg
# database: crt-rj.implanta.net.br  storageAccount: improblob01  Container já existe crt-rj
# database: crt-rn.implanta.net.br  storageAccount: improblob01  Container já existe crt-rn
# database: crt-rs.implanta.net.br  storageAccount: improblob01  Container já existe crt-rs
# database: crt-sp.implanta.net.br  storageAccount: improblob01  Container já existe crt-sp
# database: cfess-br.implanta.net.br  storageAccount: improblob02  Container já existe cfess-br
# database: cff-br.implanta.net.br  storageAccount: improblob02  Container já existe cff-br
# database: cffa-br.implanta.net.br  storageAccount: improblob02  Container já existe cffa-br
# database: cfm-br.implanta.net.br  storageAccount: improblob02  Container já existe cfm-br
# database: cfmv-br.implanta.net.br  storageAccount: improblob02  Container já existe cfmv-br
# database: cfn-br.implanta.net.br  storageAccount: improblob02  Container já existe cfn-br
# database: cfo-br.implanta.net.br  storageAccount: improblob02  Container já existe cfo-br
# database: cfp-br.implanta.net.br  storageAccount: improblob02  Container já existe cfp-br
# database: cfq-br.implanta.net.br  storageAccount: improblob02  Container já existe cfq-br
# database: cft-br.implanta.net.br  storageAccount: improblob02  Container já existe cft-br
# database: cfta-br.implanta.net.br  storageAccount: improblob02  Container já existe cfta-br
# database: codhab-df.implanta.net.br  storageAccount: improblob02  Container já existe codhab-df
# database: cofen-br.implanta.net.br  storageAccount: improblob02  Container já existe cofen-br
# database: coffito-br.implanta.net.br  storageAccount: improblob02  Container já existe coffito-br
# database: confea-br.implanta.net.br  storageAccount: improblob02  Container já existe confea-br
# database: confere-br.implanta.net.br  storageAccount: improblob02  Container já existe confere-br
# database: conferp-br.implanta.net.br  storageAccount: improblob02  Container já existe conferp-br
# database: conre-ba.implanta.net.br  storageAccount: improblob02  Container já existe conre-ba
# database: conre-df.implanta.net.br  storageAccount: improblob02  Container já existe conre-df
# database: conrerp-ba.implanta.net.br  storageAccount: improblob02  Container já existe conrerp-ba
# database: conrerp-df.implanta.net.br  storageAccount: improblob02  Container já existe conrerp-df
# database: conrerp-mg.implanta.net.br  storageAccount: improblob02  Container já existe conrerp-mg
# database: conrerp-rj.implanta.net.br  storageAccount: improblob02  Container já existe conrerp-rj
# database: conrerp-rs.implanta.net.br  storageAccount: improblob02  Container já existe conrerp-rs
# database: conrerp-sp.implanta.net.br  storageAccount: improblob02  Container já existe conrerp-sp
# database: consed-df.implanta.net.br  storageAccount: improblob02  Container já existe consed-df
# database: core-al.implanta.net.br  storageAccount: improblob02  Container já existe core-al
# database: core-am.implanta.net.br  storageAccount: improblob02  Container já existe core-am
# database: core-ap.implanta.net.br  storageAccount: improblob02  Container já existe core-ap
# database: core-ba.implanta.net.br  storageAccount: improblob02  Container já existe core-ba
# database: core-ce.implanta.net.br  storageAccount: improblob02  Container já existe core-ce
# database: core-df.implanta.net.br  storageAccount: improblob02  Container já existe core-df
# database: core-es.implanta.net.br  storageAccount: improblob02  Container já existe core-es
# database: core-go.implanta.net.br  storageAccount: improblob02  Container já existe core-go
# database: core-ma.implanta.net.br  storageAccount: improblob02  Container já existe core-ma
# database: core-mg.implanta.net.br  storageAccount: improblob02  Container já existe core-mg
# database: core-ms.implanta.net.br  storageAccount: improblob02  Container já existe core-ms
# database: core-mt.implanta.net.br  storageAccount: improblob02  Container já existe core-mt
# database: core-pa.implanta.net.br  storageAccount: improblob02  Container já existe core-pa
# database: core-pb.implanta.net.br  storageAccount: improblob02  Container já existe core-pb
# database: core-pe.implanta.net.br  storageAccount: improblob02  Container já existe core-pe
# database: core-pi.implanta.net.br  storageAccount: improblob02  Container já existe core-pi
# database: core-pr.implanta.net.br  storageAccount: improblob02  Container já existe core-pr
# database: core-rj.implanta.net.br  storageAccount: improblob02  Container já existe core-rj
# database: core-rn.implanta.net.br  storageAccount: improblob02  Container já existe core-rn
# database: core-ro.implanta.net.br  storageAccount: improblob02  Container já existe core-ro
# database: core-rs.implanta.net.br  storageAccount: improblob02  Container já existe core-rs
# database: core-sc.implanta.net.br  storageAccount: improblob02  Container já existe core-sc
# database: core-se.implanta.net.br  storageAccount: improblob02  Container já existe core-se
# database: core-sp.implanta.net.br  storageAccount: improblob02  Container já existe core-sp
# database: core-to.implanta.net.br  storageAccount: improblob02  Container já existe core-to
# database: corecon-rs.implanta.net.br  storageAccount: improblob02  Container já existe corecon-rs
# database: corecon-sp.implanta.net.br  storageAccount: improblob02  Container já existe corecon-sp
# database: coren-ac.implanta.net.br  storageAccount: improblob02  Container já existe coren-ac
# database: coren-al.implanta.net.br  storageAccount: improblob02  Container já existe coren-al
# database: coren-ap.implanta.net.br  storageAccount: improblob02  Container já existe coren-ap
# database: coren-ba.implanta.net.br  storageAccount: improblob02  Container já existe coren-ba
# database: coren-ce.implanta.net.br  storageAccount: improblob02  Container já existe coren-ce
# database: coren-df.implanta.net.br  storageAccount: improblob02  Container já existe coren-df
# database: coren-es.implanta.net.br  storageAccount: improblob02  Container já existe coren-es
# database: coren-ma.implanta.net.br  storageAccount: improblob02  Container já existe coren-ma
# database: coren-mg.implanta.net.br  storageAccount: improblob02  Container já existe coren-mg
# database: coren-ms.implanta.net.br  storageAccount: improblob02  Container já existe coren-ms
# database: coren-pa.implanta.net.br  storageAccount: improblob02  Container já existe coren-pa
# database: coren-pe.implanta.net.br  storageAccount: improblob02  Container já existe coren-pe
# database: coren-pi.implanta.net.br  storageAccount: improblob02  Container já existe coren-pi
# database: coren-pr.implanta.net.br  storageAccount: improblob02  Container já existe coren-pr
# database: coren-rj.implanta.net.br  storageAccount: improblob02  Container já existe coren-rj
# database: coren-rn.implanta.net.br  storageAccount: improblob02  Container já existe coren-rn
# database: coren-ro.implanta.net.br  storageAccount: improblob02  Container já existe coren-ro
# database: coren-rr.implanta.net.br  storageAccount: improblob02  Container já existe coren-rr
# database: coren-rs.implanta.net.br  storageAccount: improblob02  Container já existe coren-rs
# database: coren-sc.implanta.net.br  storageAccount: improblob02  Container já existe coren-sc
# database: coren-sp.implanta.net.br  storageAccount: improblob02  Container já existe coren-sp
# database: coren-to.implanta.net.br  storageAccount: improblob02  Container já existe coren-to
# database: cra-ba.implanta.net.br  storageAccount: improblob02  Container já existe cra-ba
# database: cra-df.implanta.net.br  storageAccount: improblob02  Container já existe cra-df
# database: cra-go.implanta.net.br  storageAccount: improblob02  Container já existe cra-go
# database: cress-ac.implanta.net.br  storageAccount: improblob02  Container já existe cress-ac
# database: cress-al.implanta.net.br  storageAccount: improblob02  Container já existe cress-al
# database: cress-am.implanta.net.br  storageAccount: improblob02  Container já existe cress-am
# database: cress-ap.implanta.net.br  storageAccount: improblob02  Container já existe cress-ap
# database: cress-ba.implanta.net.br  storageAccount: improblob02  Container já existe cress-ba
# database: cress-ce.implanta.net.br  storageAccount: improblob02  Container já existe cress-ce
# database: cress-df.implanta.net.br  storageAccount: improblob02  Container já existe cress-df
# database: cress-es.implanta.net.br  storageAccount: improblob02  Container já existe cress-es
# database: cress-go.implanta.net.br  storageAccount: improblob02  Container já existe cress-go
# database: cress-ma.implanta.net.br  storageAccount: improblob02  Container já existe cress-ma
# database: cress-mg.implanta.net.br  storageAccount: improblob02  Container já existe cress-mg
# database: cress-ms.implanta.net.br  storageAccount: improblob02  Container já existe cress-ms
# database: cress-mt.implanta.net.br  storageAccount: improblob02  Container já existe cress-mt
# database: cress-pa.implanta.net.br  storageAccount: improblob02  Container já existe cress-pa
# database: cress-pb.implanta.net.br  storageAccount: improblob02  Container já existe cress-pb
# database: cress-pe.implanta.net.br  storageAccount: improblob02  Container já existe cress-pe
# database: cress-pi.implanta.net.br  storageAccount: improblob02  Container já existe cress-pi
# database: cress-pr.implanta.net.br  storageAccount: improblob02  Container já existe cress-pr
# database: cress-rj.implanta.net.br  storageAccount: improblob02  Container já existe cress-rj
# database: cress-rn.implanta.net.br  storageAccount: improblob02  Container já existe cress-rn
# database: cress-ro.implanta.net.br  storageAccount: improblob02  Container já existe cress-ro
# database: cress-rr.implanta.net.br  storageAccount: improblob02  Container já existe cress-rr
# database: cress-rs.implanta.net.br  storageAccount: improblob02  Container já existe cress-rs
# database: cress-sc.implanta.net.br  storageAccount: improblob02  Container já existe cress-sc
# database: cress-se.implanta.net.br  storageAccount: improblob02  Container já existe cress-se
# database: cress-sp.implanta.net.br  storageAccount: improblob02  Container já existe cress-sp
# database: cress-to.implanta.net.br  storageAccount: improblob02  Container já existe cress-to
# database: cro-sp.implanta.net.br  storageAccount: improblob02  Container já existe cro-sp
# database: crtr-02.implanta.net.br  storageAccount: improblob02  Container já existe crtr-02
# database: crtr-03.implanta.net.br  storageAccount: improblob02  Container já existe crtr-03
# database: crtr-12.implanta.net.br  storageAccount: improblob02  Container já existe crtr-12
# database: crtr-sp.implanta.net.br  storageAccount: improblob02  Container já existe crtr-sp
# database: crea-ac.implanta.net.br  storageAccount: improblob03  Container já existe crea-ac
# database: crea-al.implanta.net.br  storageAccount: improblob03  Container já existe crea-al
# database: crea-am.implanta.net.br  storageAccount: improblob03  Container já existe crea-am
# database: crea-ap.implanta.net.br  storageAccount: improblob03  Container já existe crea-ap
# database: crea-ba.implanta.net.br  storageAccount: improblob03  Container já existe crea-ba
# database: crea-ce.implanta.net.br  storageAccount: improblob03  Container já existe crea-ce
# database: crea-df.implanta.net.br  storageAccount: improblob03  Container já existe crea-df
# database: crea-es.implanta.net.br  storageAccount: improblob03  Container já existe crea-es
# database: crea-go.implanta.net.br  storageAccount: improblob03  Container já existe crea-go
# database: crea-mg.implanta.net.br  storageAccount: improblob03  Container já existe crea-mg
# database: crea-ms.implanta.net.br  storageAccount: improblob03  Container já existe crea-ms
# database: crea-mt.implanta.net.br  storageAccount: improblob03  Container já existe crea-mt
# database: crea-pa.implanta.net.br  storageAccount: improblob03  Container já existe crea-pa
# database: crea-pe.implanta.net.br  storageAccount: improblob03  Container já existe crea-pe
# database: crea-pr.implanta.net.br  storageAccount: improblob03  Container já existe crea-pr
# database: crea-rj.implanta.net.br  storageAccount: improblob03  Container já existe crea-rj
# database: crea-rn.implanta.net.br  storageAccount: improblob03  Container já existe crea-rn
# database: crea-ro.implanta.net.br  storageAccount: improblob03  Container já existe crea-ro
# database: crea-rr.implanta.net.br  storageAccount: improblob03  Container já existe crea-rr
# database: crea-rs.implanta.net.br  storageAccount: improblob03  Container já existe crea-rs
# database: crea-sc.implanta.net.br  storageAccount: improblob03  Container já existe crea-sc
# database: crea-se.implanta.net.br  storageAccount: improblob03  Container já existe crea-se
# database: crea-sp.implanta.net.br  storageAccount: improblob03  Container já existe crea-sp
# database: crea-to.implanta.net.br  storageAccount: improblob03  Container já existe crea-to
# database: cref-rs.implanta.net.br  storageAccount: improblob03  Container já existe cref-rs
# database: cref-sp.implanta.net.br  storageAccount: improblob03  Container já existe cref-sp
# database: crefito-ba.implanta.net.br  storageAccount: improblob03  Container já existe crefito-ba
# database: crefito-ce.implanta.net.br  storageAccount: improblob03  Container já existe crefito-ce
# database: crefito-df.implanta.net.br  storageAccount: improblob03  Container já existe crefito-df
# database: crefito-es.implanta.net.br  storageAccount: improblob03  Container já existe crefito-es
# database: crefito-ma.implanta.net.br  storageAccount: improblob03  Container já existe crefito-ma
# database: crefito-mg.implanta.net.br  storageAccount: improblob03  Container já existe crefito-mg
# database: crefito-ms.implanta.net.br  storageAccount: improblob03  Container já existe crefito-ms
# database: crefito-mt.implanta.net.br  storageAccount: improblob03  Container já existe crefito-mt
# database: crefito-pa.implanta.net.br  storageAccount: improblob03  Container já existe crefito-pa
# database: crefito-pe.implanta.net.br  storageAccount: improblob03  Container já existe crefito-pe
# database: crefito-pi.implanta.net.br  storageAccount: improblob03  Container já existe crefito-pi
# database: crefito-pr.implanta.net.br  storageAccount: improblob03  Container já existe crefito-pr
# database: crefito-rj.implanta.net.br  storageAccount: improblob03  Container já existe crefito-rj
# database: crefito-rs.implanta.net.br  storageAccount: improblob03  Container já existe crefito-rs
# database: crefito-sc.implanta.net.br  storageAccount: improblob03  Container já existe crefito-sc
# database: crefito-sp.implanta.net.br  storageAccount: improblob03  Container já existe crefito-sp
# database: crf-ac.implanta.net.br  storageAccount: improblob03  Container já existe crf-ac
# database: crf-al.implanta.net.br  storageAccount: improblob03  Container já existe crf-al
# database: crf-am.implanta.net.br  storageAccount: improblob03  Container já existe crf-am
# database: crf-ap.implanta.net.br  storageAccount: improblob03  Container já existe crf-ap
# database: crf-ba.implanta.net.br  storageAccount: improblob03  Container já existe crf-ba
# database: crf-ce.implanta.net.br  storageAccount: improblob03  Container já existe crf-ce
# database: crf-df.implanta.net.br  storageAccount: improblob03  Container já existe crf-df
# database: crf-es.implanta.net.br  storageAccount: improblob03  Container já existe crf-es
# database: crf-go.implanta.net.br  storageAccount: improblob03  Container já existe crf-go
# database: crf-ma.implanta.net.br  storageAccount: improblob03  Container já existe crf-ma
# database: crf-mg.implanta.net.br  storageAccount: improblob03  Container já existe crf-mg
# database: crf-ms.implanta.net.br  storageAccount: improblob03  Container já existe crf-ms
# database: crf-mt.implanta.net.br  storageAccount: improblob03  Container já existe crf-mt
# database: crf-pa.implanta.net.br  storageAccount: improblob03  Container já existe crf-pa
# database: crf-pb.implanta.net.br  storageAccount: improblob03  Container já existe crf-pb
# database: crf-pe.implanta.net.br  storageAccount: improblob03  Container já existe crf-pe
# database: crf-pi.implanta.net.br  storageAccount: improblob03  Container já existe crf-pi
# database: crf-pr.implanta.net.br  storageAccount: improblob03  Container já existe crf-pr
# database: crf-rj.implanta.net.br  storageAccount: improblob03  Container já existe crf-rj
# database: crf-rn.implanta.net.br  storageAccount: improblob03  Container já existe crf-rn
# database: crf-ro.implanta.net.br  storageAccount: improblob03  Container já existe crf-ro
# database: crf-rr.implanta.net.br  storageAccount: improblob03  Container já existe crf-rr
# database: crf-rs.implanta.net.br  storageAccount: improblob03  Container já existe crf-rs
# database: crf-sc.implanta.net.br  storageAccount: improblob03  Container já existe crf-sc
# database: crf-se.implanta.net.br  storageAccount: improblob03  Container já existe crf-se
# database: crf-sp.implanta.net.br  storageAccount: improblob03  Container já existe crf-sp
# database: crf-to.implanta.net.br  storageAccount: improblob03  Container já existe crf-to
# database: crfa-am.implanta.net.br  storageAccount: improblob03  Container já existe crfa-am
# database: crfa-ce.implanta.net.br  storageAccount: improblob03  Container já existe crfa-ce
# database: crfa-go.implanta.net.br  storageAccount: improblob03  Container já existe crfa-go
# database: crfa-mg.implanta.net.br  storageAccount: improblob03  Container já existe crfa-mg
# database: crfa-pe.implanta.net.br  storageAccount: improblob03  Container já existe crfa-pe
# database: crfa-pr.implanta.net.br  storageAccount: improblob03  Container já existe crfa-pr
# database: crfa-rj.implanta.net.br  storageAccount: improblob03  Container já existe crfa-rj
# database: crfa-rs.implanta.net.br  storageAccount: improblob03  Container já existe crfa-rs
# database: crfa-sp.implanta.net.br  storageAccount: improblob03  Container já existe crfa-sp
# database: crm-ac.implanta.net.br  storageAccount: improblob03  Container já existe crm-ac
# database: crm-al.implanta.net.br  storageAccount: improblob03  Container já existe crm-al
# database: crm-am.implanta.net.br  storageAccount: improblob03  Container já existe crm-am
# database: crm-ap.implanta.net.br  storageAccount: improblob03  Container já existe crm-ap
# database: crm-ba.implanta.net.br  storageAccount: improblob03  Container já existe crm-ba
# database: crm-ce.implanta.net.br  storageAccount: improblob03  Container já existe crm-ce
# database: crm-df.implanta.net.br  storageAccount: improblob03  Container já existe crm-df
# database: crm-es.implanta.net.br  storageAccount: improblob03  Container já existe crm-es
# database: crm-go.implanta.net.br  storageAccount: improblob03  Container já existe crm-go
# database: crm-ma.implanta.net.br  storageAccount: improblob03  Container já existe crm-ma
# database: crm-mg.implanta.net.br  storageAccount: improblob03  Container já existe crm-mg
# database: crm-ms.implanta.net.br  storageAccount: improblob03  Container já existe crm-ms
# database: crm-mt.implanta.net.br  storageAccount: improblob03  Container já existe crm-mt
# database: crm-pa.implanta.net.br  storageAccount: improblob03  Container já existe crm-pa
# database: crm-pb.implanta.net.br  storageAccount: improblob03  Container já existe crm-pb
# database: crm-pe.implanta.net.br  storageAccount: improblob03  Container já existe crm-pe
# database: crm-pi.implanta.net.br  storageAccount: improblob03  Container já existe crm-pi
# database: crm-pr.implanta.net.br  storageAccount: improblob03  Container já existe crm-pr
# database: crm-rj.implanta.net.br  storageAccount: improblob03  Container já existe crm-rj
# database: crm-rn.implanta.net.br  storageAccount: improblob03  Container já existe crm-rn
# database: crm-ro.implanta.net.br  storageAccount: improblob03  Container já existe crm-ro
# database: crm-rr.implanta.net.br  storageAccount: improblob03  Container já existe crm-rr
# database: crm-rs.implanta.net.br  storageAccount: improblob03  Container já existe crm-rs
# database: crm-sc.implanta.net.br  storageAccount: improblob03  Container já existe crm-sc
# database: crm-se.implanta.net.br  storageAccount: improblob03  Container já existe crm-se
# database: crm-to.implanta.net.br  storageAccount: improblob03  Container já existe crm-to
# database: crmv-al.implanta.net.br  storageAccount: improblob03  Container já existe crmv-al
# database: crmv-ba.implanta.net.br  storageAccount: improblob03  Container já existe crmv-ba
# database: crmv-ce.implanta.net.br  storageAccount: improblob03  Container já existe crmv-ce
# database: crmv-df.implanta.net.br  storageAccount: improblob03  Container já existe crmv-df
# database: crmv-go.implanta.net.br  storageAccount: improblob03  Container já existe crmv-go
# database: crmv-mg.implanta.net.br  storageAccount: improblob03  Container já existe crmv-mg
# database: crmv-ms.implanta.net.br  storageAccount: improblob03  Container já existe crmv-ms
# database: crmv-pb.implanta.net.br  storageAccount: improblob03  Container já existe crmv-pb
# database: crmv-pe.implanta.net.br  storageAccount: improblob03  Container já existe crmv-pe
# database: crmv-pi.implanta.net.br  storageAccount: improblob03  Container já existe crmv-pi
# database: crmv-pr.implanta.net.br  storageAccount: improblob03  Container já existe crmv-pr
# database: crmv-rj.implanta.net.br  storageAccount: improblob03  Container já existe crmv-rj
# database: crmv-rn.implanta.net.br  storageAccount: improblob03  Container já existe crmv-rn
# database: crmv-ro.implanta.net.br  storageAccount: improblob03  Container já existe crmv-ro
# database: crmv-rs.implanta.net.br  storageAccount: improblob03  Container já existe crmv-rs
# database: crmv-sc.implanta.net.br  storageAccount: improblob03  Container já existe crmv-sc
# database: crmv-se.implanta.net.br  storageAccount: improblob03  Container já existe crmv-se
# database: crmv-sp.implanta.net.br  storageAccount: improblob03  Container já existe crmv-sp
# database: crmv-to.implanta.net.br  storageAccount: improblob03  Container já existe crmv-to
# database: crn-04.implanta.net.br  storageAccount: improblob03  Container já existe crn-04
# database: crn-06.implanta.net.br  storageAccount: improblob03  Container já existe crn-06
# database: crn-ba.implanta.net.br  storageAccount: improblob03  Container já existe crn-ba
# database: crn-df.implanta.net.br  storageAccount: improblob03  Container já existe crn-df
# database: crn-mg.implanta.net.br  storageAccount: improblob03  Container já existe crn-mg
# database: crn-pa.implanta.net.br  storageAccount: improblob03  Container já existe crn-pa
# database: crn-pr.implanta.net.br  storageAccount: improblob03  Container já existe crn-pr
# database: crn-rs.implanta.net.br  storageAccount: improblob03  Container já existe crn-rs
# database: crn-sc.implanta.net.br  storageAccount: improblob03  Container já existe crn-sc
# database: crn-sp.implanta.net.br  storageAccount: improblob03  Container já existe crn-sp
# database: crp-ba.implanta.net.br  storageAccount: improblob03  Container já existe crp-ba
# database: crp-ce.implanta.net.br  storageAccount: improblob03  Container já existe crp-ce
# database: crp-df.implanta.net.br  storageAccount: improblob03  Container já existe crp-df
# database: crp-es.implanta.net.br  storageAccount: improblob03  Container já existe crp-es
# database: crp-go.implanta.net.br  storageAccount: improblob03  Container já existe crp-go
# database: crp-ma.implanta.net.br  storageAccount: improblob03  Container já existe crp-ma
# database: crp-mg.implanta.net.br  storageAccount: improblob03  Container já existe crp-mg
# database: crp-ms.implanta.net.br  storageAccount: improblob03  Container já existe crp-ms
# database: crp-mt.implanta.net.br  storageAccount: improblob03  Container já existe crp-mt
# database: crp-pa.implanta.net.br  storageAccount: improblob03  Container já existe crp-pa
# database: crp-pb.implanta.net.br  storageAccount: improblob03  Container já existe crp-pb
# database: crp-pe.implanta.net.br  storageAccount: improblob03  Container já existe crp-pe
# database: crp-pi.implanta.net.br  storageAccount: improblob03  Container já existe crp-pi
# database: crp-rj.implanta.net.br  storageAccount: improblob03  Container já existe crp-rj
# database: crp-rn.implanta.net.br  storageAccount: improblob03  Container já existe crp-rn
# database: crp-rs.implanta.net.br  storageAccount: improblob03  Container já existe crp-rs
# database: crp-sc.implanta.net.br  storageAccount: improblob03  Container já existe crp-sc
# database: crp-se.implanta.net.br  storageAccount: improblob03  Container já existe crp-se
# database: crp-sp.implanta.net.br  storageAccount: improblob03  Container já existe crp-sp
# database: crp-to.implanta.net.br  storageAccount: improblob03  Container já existe crp-to
# database: crq-al.implanta.net.br  storageAccount: improblob03  Container já existe crq-al
# database: oab-ac.implanta.net.br  storageAccount: improblob03  Container já existe oab-ac
# database: oab-al.implanta.net.br  storageAccount: improblob03  Container já existe oab-al
# database: oab-am.implanta.net.br  storageAccount: improblob03  Container já existe oab-am
# database: oab-ap.implanta.net.br  storageAccount: improblob03  Container já existe oab-ap
# database: oab-ba.implanta.net.br  storageAccount: improblob03  Container já existe oab-ba
# database: oab-ce.implanta.net.br  storageAccount: improblob03  Container já existe oab-ce
# database: oab-df.implanta.net.br  storageAccount: improblob03  Container já existe oab-df
# database: oab-ms.implanta.net.br  storageAccount: improblob03  Container já existe oab-ms
# database: oab-pa.implanta.net.br  storageAccount: improblob03  Container já existe oab-pa
# database: oab-pi.implanta.net.br  storageAccount: improblob03  Container já existe oab-pi
# database: oab-rn.implanta.net.br  storageAccount: improblob03  Container já existe oab-rn
# database: oab-rr.implanta.net.br  storageAccount: improblob03  Container já existe oab-rr
# database: oab-rs.implanta.net.br  storageAccount: improblob03  Container já existe oab-rs
# database: oab-se.implanta.net.br  storageAccount: improblob03  Container já existe oab-se

# %% [markdown]
# ## recupera os dados finais para gerar o excel

# %%
dados = datasource[['Cliente','Categoria','MigracaoDiaria','UtilizaAzure','StorageAccount','ContainerAzureStorageArquivosAnexos', 'CaminhoCacheLocalAzureStorageArquivosAnexos','ConnectionStringAzureStorageArquivosAnexos','HorarioMigracaoArquivosAnexosParaAzureStorage']]

# %% [markdown]
# ## Gera o excel com as configurações

# %%
dados.to_excel('D:\Ondrive\OneDrive - Implanta Informatica\Migração arquivos Anexos\ConfiguracaoFinalStorageAccounts.xlsx')

# %% [markdown]
# ## cria um dataset com as seguintes categorias a ser configuradas
# #cau
# #core
# #coren
# #crea
# #cra
# #cro

# %%
dados["Categoria"].value_counts()
# Out:
# cau        28
# cress      27
# crf        27
# crm        26
# cro        26
# core       25
# cra        24
# crea       24
# coren      22
# crp        20
# crq        20
# crmv       19
# crefito    16
# oab        14
# crt        11
# crn        10
# crfa        9
# conrerp     6
# crtr        4
# corecon     2
# crbm        2
# conre       2
# cref        2
# consed      1
# confea      1
# cfta        1
# cfess       1
# cfmv        1
# cfn         1
# conferp     1
# cffa        1
# cff         1
# cfq         1
# cfo         1
# codhab      1
# cft         1
# cfa         1
# cfp         1
# coffito     1
# cfm         1
# cofen       1
# confere     1
# Name: Categoria, dtype: int64

# %%
filter_categorias = dados.query("Categoria in('cau','core','coren','crea','cra','cro','crf','confere','crn','crt','oab','crefito','crmv','crq','crp') and  UtilizaAzure =='NAO'")[['Cliente','Categoria','MigracaoDiaria','UtilizaAzure','StorageAccount','ContainerAzureStorageArquivosAnexos','CaminhoCacheLocalAzureStorageArquivosAnexos','ConnectionStringAzureStorageArquivosAnexos','HorarioMigracaoArquivosAnexosParaAzureStorage']]

# %% [markdown]
# ## mostra os 5 primeiros

# %%
filter_categorias.head(5)
# Out:
#                   Cliente Categoria  MigracaoDiaria UtilizaAzure  \
# 1  cau-al.implanta.net.br       cau             500          NAO
# 2  cau-am.implanta.net.br       cau             500          NAO
# 3  cau-ap.implanta.net.br       cau             500          NAO
# 4  cau-ba.implanta.net.br       cau             500          NAO
# 5  cau-br.implanta.net.br       cau             500          NAO
#
#   StorageAccount ContainerAzureStorageArquivosAnexos  \
# 1    improblob01                              cau-al
# 2    improblob01                              cau-am
# 3    improblob01                              cau-ap
# 4    improblob01                              cau-ba
# 5    improblob01                              cau-br
#
#   CaminhoCacheLocalAzureStorageArquivosAnexos  \
# 1                  D:\temp_blob_azure\cau-al\
# 2                  D:\temp_blob_azure\cau-am\
# 3                  D:\temp_blob_azure\cau-ap\
# 4                  D:\temp_blob_azure\cau-ba\
# 5                  D:\temp_blob_azure\cau-br\
#
#           ConnectionStringAzureStorageArquivosAnexos  \
# 1  DefaultEndpointsProtocol=https;AccountName=imp...
# 2  DefaultEndpointsProtocol=https;AccountName=imp...
# 3  DefaultEndpointsProtocol=https;AccountName=imp...
# 4  DefaultEndpointsProtocol=https;AccountName=imp...
# 5  DefaultEndpointsProtocol=https;AccountName=imp...
#
#   HorarioMigracaoArquivosAnexosParaAzureStorage
# 1                                      23:00:00
# 2                                      21:00:00
# 3                                      23:00:00
# 4                                      22:00:00
# 5                                      01:00:00

# %% [markdown]
# ## mostra os 5 ultimos

# %%
filter_categorias.tail(5)
# Out:
#                      Cliente Categoria  MigracaoDiaria UtilizaAzure  \
# 236  crea-rs.implanta.net.br      crea             500          NAO
# 237  crea-sc.implanta.net.br      crea             500          NAO
# 238  crea-se.implanta.net.br      crea             500          NAO
# 239  crea-sp.implanta.net.br      crea             500          NAO
# 240  crea-to.implanta.net.br      crea             500          NAO
#
#     StorageAccount ContainerAzureStorageArquivosAnexos  \
# 236    improblob03                             crea-rs
# 237    improblob03                             crea-sc
# 238    improblob03                             crea-se
# 239    improblob03                             crea-sp
# 240    improblob03                             crea-to
#
#     CaminhoCacheLocalAzureStorageArquivosAnexos  \
# 236                 D:\temp_blob_azure\crea-rs\
# 237                 D:\temp_blob_azure\crea-sc\
# 238                 D:\temp_blob_azure\crea-se\
# 239                 D:\temp_blob_azure\crea-sp\
# 240                 D:\temp_blob_azure\crea-to\
#
#             ConnectionStringAzureStorageArquivosAnexos  \
# 236  DefaultEndpointsProtocol=https;AccountName=imp...
# 237  DefaultEndpointsProtocol=https;AccountName=imp...
# 238  DefaultEndpointsProtocol=https;AccountName=imp...
# 239  DefaultEndpointsProtocol=https;AccountName=imp...
# 240  DefaultEndpointsProtocol=https;AccountName=imp...
#
#     HorarioMigracaoArquivosAnexosParaAzureStorage
# 236                                      23:00:00
# 237                                      01:00:00
# 238                                      22:00:00
# 239                                      19:00:00
# 240                                      19:00:00

# %% [markdown]
# ## Conecta no banco de dados para alterar as configurações conforme a planilha

# %%
filter_categorias.shape
# Out:
# (233, 9)

# %%
server = 'rgprd-sqlsrv-prd01.database.windows.net'
database = 'cau-ac.implanta.net.br'
username = 'wesley.neves@implantainformatica.com.br'
password = 'enzo_96086512'
driver= '{ODBC Driver 17 for SQL Server}'

# %%
def get_conection(driver,server,database,username,password):
    _conexao = PDB.connect('DRIVER='+driver+';SERVER='+server+';PORT=1433;DATABASE='+database+';UID='+username+';PWD='+ password +';Authentication=ActiveDirectoryPassword')
    return _conexao

# %%
filter_categorias.query("Cliente =='cau-al.implanta.net.br'")
# Out:
#                   Cliente Categoria  MigracaoDiaria UtilizaAzure  \
# 1  cau-al.implanta.net.br       cau             500          NAO
#
#   StorageAccount ContainerAzureStorageArquivosAnexos  \
# 1    improblob01                              cau-al
#
#   CaminhoCacheLocalAzureStorageArquivosAnexos  \
# 1                  D:\temp_blob_azure\cau-al\
#
#           ConnectionStringAzureStorageArquivosAnexos  \
# 1  DefaultEndpointsProtocol=https;AccountName=imp...
#
#   HorarioMigracaoArquivosAnexosParaAzureStorage
# 1                                      23:00:00

# %% [markdown]
# ## script base para alteração das configurações

# %%
base_script_update = "UPDATE C SET C.Valor ='{0}' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='{1}'"
print(base_script_update)
# Out:
# UPDATE C SET C.Valor ='{0}' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='{1}'

# %%
base_script_insert = "INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', '{0}', '{1}', 0);"

print(base_script_insert)
# Out:
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', '{0}', '{1}', 0);

# %%
base_script_select ="select top 1 valor from sistema.Configuracoes where Configuracao ='{0}'"
print(base_script_select.format('QuantidadeDeArquivosMigradosPorExecucao'))
# Out:
# select top 1 valor from sistema.Configuracoes where Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'

# %%
filter_categorias.query("Categoria =='cau'")
# Out:
#                    Cliente Categoria  MigracaoDiaria UtilizaAzure  \
# 1   cau-al.implanta.net.br       cau             500          NAO
# 2   cau-am.implanta.net.br       cau             500          NAO
# 3   cau-ap.implanta.net.br       cau             500          NAO
# 4   cau-ba.implanta.net.br       cau             500          NAO
# 5   cau-br.implanta.net.br       cau             500          NAO
# 6   cau-ce.implanta.net.br       cau             500          NAO
# 7   cau-df.implanta.net.br       cau             500          NAO
# 8   cau-es.implanta.net.br       cau             500          NAO
# 9   cau-go.implanta.net.br       cau             500          NAO
# 10  cau-ma.implanta.net.br       cau             500          NAO
# 11  cau-mg.implanta.net.br       cau             500          NAO
# 12  cau-ms.implanta.net.br       cau             500          NAO
# 13  cau-mt.implanta.net.br       cau             500          NAO
# 14  cau-pa.implanta.net.br       cau             500          NAO
# 15  cau-pb.implanta.net.br       cau             500          NAO
# 16  cau-pe.implanta.net.br       cau             500          NAO
# 17  cau-pi.implanta.net.br       cau             500          NAO
# 18  cau-pr.implanta.net.br       cau             500          NAO
# 20  cau-rn.implanta.net.br       cau             500          NAO
# 21  cau-ro.implanta.net.br       cau             500          NAO
# 22  cau-rr.implanta.net.br       cau             500          NAO
# 23  cau-rs.implanta.net.br       cau             500          NAO
# 24  cau-sc.implanta.net.br       cau             500          NAO
# 25  cau-se.implanta.net.br       cau             500          NAO
# 27  cau-to.implanta.net.br       cau             500          NAO
#
#    StorageAccount ContainerAzureStorageArquivosAnexos  \
# 1     improblob01                              cau-al
# 2     improblob01                              cau-am
# 3     improblob01                              cau-ap
# 4     improblob01                              cau-ba
# 5     improblob01                              cau-br
# 6     improblob01                              cau-ce
# 7     improblob01                              cau-df
# 8     improblob01                              cau-es
# 9     improblob01                              cau-go
# 10    improblob01                              cau-ma
# 11    improblob01                              cau-mg
# 12    improblob01                              cau-ms
# 13    improblob01                              cau-mt
# 14    improblob01                              cau-pa
# 15    improblob01                              cau-pb
# 16    improblob01                              cau-pe
# 17    improblob01                              cau-pi
# 18    improblob01                              cau-pr
# 20    improblob01                              cau-rn
# 21    improblob01                              cau-ro
# 22    improblob01                              cau-rr
# 23    improblob01                              cau-rs
# 24    improblob01                              cau-sc
# 25    improblob01                              cau-se
# 27    improblob01                              cau-to
#
#    CaminhoCacheLocalAzureStorageArquivosAnexos  \
# 1                   D:\temp_blob_azure\cau-al\
# 2                   D:\temp_blob_azure\cau-am\
# 3                   D:\temp_blob_azure\cau-ap\
# 4                   D:\temp_blob_azure\cau-ba\
# 5                   D:\temp_blob_azure\cau-br\
# 6                   D:\temp_blob_azure\cau-ce\
# 7                   D:\temp_blob_azure\cau-df\
# 8                   D:\temp_blob_azure\cau-es\
# 9                   D:\temp_blob_azure\cau-go\
# 10                  D:\temp_blob_azure\cau-ma\
# 11                  D:\temp_blob_azure\cau-mg\
# 12                  D:\temp_blob_azure\cau-ms\
# 13                  D:\temp_blob_azure\cau-mt\
# 14                  D:\temp_blob_azure\cau-pa\
# 15                  D:\temp_blob_azure\cau-pb\
# 16                  D:\temp_blob_azure\cau-pe\
# 17                  D:\temp_blob_azure\cau-pi\
# 18                  D:\temp_blob_azure\cau-pr\
# 20                  D:\temp_blob_azure\cau-rn\
# 21                  D:\temp_blob_azure\cau-ro\
# 22                  D:\temp_blob_azure\cau-rr\
# 23                  D:\temp_blob_azure\cau-rs\
# 24                  D:\temp_blob_azure\cau-sc\
# 25                  D:\temp_blob_azure\cau-se\
# 27                  D:\temp_blob_azure\cau-to\
#
#            ConnectionStringAzureStorageArquivosAnexos  \
# 1   DefaultEndpointsProtocol=https;AccountName=imp...
# 2   DefaultEndpointsProtocol=https;AccountName=imp...
# 3   DefaultEndpointsProtocol=https;AccountName=imp...
# 4   DefaultEndpointsProtocol=https;AccountName=imp...
# 5   DefaultEndpointsProtocol=https;AccountName=imp...
# 6   DefaultEndpointsProtocol=https;AccountName=imp...
# 7   DefaultEndpointsProtocol=https;AccountName=imp...
# 8   DefaultEndpointsProtocol=https;AccountName=imp...
# 9   DefaultEndpointsProtocol=https;AccountName=imp...
# 10  DefaultEndpointsProtocol=https;AccountName=imp...
# 11  DefaultEndpointsProtocol=https;AccountName=imp...
# 12  DefaultEndpointsProtocol=https;AccountName=imp...
# 13  DefaultEndpointsProtocol=https;AccountName=imp...
# 14  DefaultEndpointsProtocol=https;AccountName=imp...
# 15  DefaultEndpointsProtocol=https;AccountName=imp...
# 16  DefaultEndpointsProtocol=https;AccountName=imp...
# 17  DefaultEndpointsProtocol=https;AccountName=imp...
# 18  DefaultEndpointsProtocol=https;AccountName=imp...
# 20  DefaultEndpointsProtocol=https;AccountName=imp...
# 21  DefaultEndpointsProtocol=https;AccountName=imp...
# 22  DefaultEndpointsProtocol=https;AccountName=imp...
# 23  DefaultEndpointsProtocol=https;AccountName=imp...
# 24  DefaultEndpointsProtocol=https;AccountName=imp...
# 25  DefaultEndpointsProtocol=https;AccountName=imp...
# 27  DefaultEndpointsProtocol=https;AccountName=imp...
#
#    HorarioMigracaoArquivosAnexosParaAzureStorage
# 1                                       23:00:00
# 2                                       21:00:00
# 3                                       23:00:00
# 4                                       22:00:00
# 5                                       01:00:00
# 6                                       22:00:00
# 7                                       24:00:00
# 8                                       24:00:00
# 9                                       19:00:00
# 10                                      02:00:00
# 11                                      24:00:00
# 12                                      01:00:00
# 13                                      02:00:00
# 14                                      23:00:00
# 15                                      24:00:00
# 16                                      21:00:00
# 17                                      23:00:00
# 18                                      01:00:00
# 20                                      19:00:00
# 21                                      03:00:00
# 22                                      02:00:00
# 23                                      20:00:00
# 24                                      03:00:00
# 25                                      20:00:00
# 27                                      21:00:00

# %% [markdown]
# ## categorias configuradas

# %%
filter_categorias.shape
# Out:
# (233, 9)

# %%
filter_categorias['Categoria'].value_counts()
# Out:
# crf        27
# cau        25
# core       25
# crea       24
# coren      22
# crp        20
# crmv       19
# crq        18
# crefito    16
# oab        13
# crt        11
# crn        10
# confere     1
# cra         1
# cro         1
# Name: Categoria, dtype: int64

# %%
for index , row in filter_categorias.iterrows():
    database = row["Cliente"]
    categoria = row["Categoria"]
    migracaoDiaria = row["MigracaoDiaria"]
    UtilizaAzure = row["UtilizaAzure"]
    
    storageAccount =  row["StorageAccount"]
    container =row["ContainerAzureStorageArquivosAnexos"]
    horarioMigracao =row["HorarioMigracaoArquivosAnexosParaAzureStorage"]
    connect_str_to_storage = row["ConnectionStringAzureStorageArquivosAnexos"]
    cLocalAzureStorageArquivosAnexos =row["CaminhoCacheLocalAzureStorageArquivosAnexos"]

   
    blob_service_client = BlobServiceClient.from_connection_string(connect_str_to_storage)
    existContainer = blob_service_client.get_container_client(container).exists()

    
    if(existContainer ==True):
        _con = get_conection(driver,server,database,username,password)
        cursor = _con.cursor()

        #Valida se o cliente já está configurado
        query = base_script_select.format('UsaAzureStorageArquivosAnexos')
        cursor.execute(query)

        clienteConfigurado = cursor.fetchone()

        if(clienteConfigurado is not None):
            if(clienteConfigurado[0] == 'true'):
                print(database,'Já configurado')
                _con.commit()
                cursor.close()
                continue



        # configura  QuantidadeDeArquivosMigradosPorExecucao
        print('configurando ',database)
        query = base_script_select.format('QuantidadeDeArquivosMigradosPorExecucao')
        cursor.execute(query)

        existe_QuantidadeDeArquivosMigradosPorExecucao = cursor.fetchone()
        
        if(existe_QuantidadeDeArquivosMigradosPorExecucao is not None):
            if(existe_QuantidadeDeArquivosMigradosPorExecucao[0] != '500'):
                query_updateConfiguracao =base_script_update.format(500,'QuantidadeDeArquivosMigradosPorExecucao')
                print(query_updateConfiguracao)
                cursor.execute(query_updateConfiguracao)
        else:
            query_insert_configuracao = base_script_insert.format('QuantidadeDeArquivosMigradosPorExecucao',500)
            print(query_insert_configuracao)
            cursor.execute(query_insert_configuracao)

        
        #configura  HorarioMigracaoArquivosAnexosParaAzureStorage
        query = base_script_select.format('HorarioMigracaoArquivosAnexosParaAzureStorage')
        cursor.execute(query)

        existe_HorarioMigracaoArquivosAnexosParaAzureStorage =cursor.fetchone()
        
        if(existe_HorarioMigracaoArquivosAnexosParaAzureStorage is None):
            query_insert_configuracao = base_script_insert.format('HorarioMigracaoArquivosAnexosParaAzureStorage',horarioMigracao)
            cursor.execute(query_insert_configuracao)
            print(query_insert_configuracao)
        
        

            #configura  CaminhoCacheLocalAzureStorageArquivosAnexos
        query = base_script_select.format('CaminhoCacheLocalAzureStorageArquivosAnexos')
        cursor.execute(query)

        existe_CaminhoCacheLocalAzureStorageArquivosAnexos = cursor.fetchone()
        if(existe_CaminhoCacheLocalAzureStorageArquivosAnexos is None):
            query_insert_configuracao = base_script_insert.format('CaminhoCacheLocalAzureStorageArquivosAnexos',
        cLocalAzureStorageArquivosAnexos)
            cursor.execute(query_insert_configuracao)
            print(query_insert_configuracao)


        #configura  ConnectionStringAzureStorageArquivosAnexos
        query = base_script_select.format('ConnectionStringAzureStorageArquivosAnexos')
        cursor.execute(query)

        existe_ConnectionStringAzureStorageArquivosAnexos = cursor.fetchone()
        if(existe_ConnectionStringAzureStorageArquivosAnexos is None):
            query_insert_configuracao = base_script_insert.format('ConnectionStringAzureStorageArquivosAnexos',connect_str_to_storage)
            cursor.execute(query_insert_configuracao)
            print(query_insert_configuracao)
        
        #configura  ConnectionStringAzureStorageArquivosAnexos
        query = base_script_select.format('ContainerAzureStorageArquivosAnexos')
        cursor.execute(query)

        existe_ContainerAzureStorageArquivosAnexos = cursor.fetchone()
        if(existe_ContainerAzureStorageArquivosAnexos is None):
            query_insert_configuracao = base_script_insert.format('ContainerAzureStorageArquivosAnexos',container)
            cursor.execute(query_insert_configuracao)
            print(query_insert_configuracao)
        

        #configura  UsaAzureStorageArquivosAnexos
        query = base_script_select.format('UsaAzureStorageArquivosAnexos')
        cursor.execute(query)

        existe_UsaAzureStorageArquivosAnexos = cursor.fetchone()
        if(existe_UsaAzureStorageArquivosAnexos is None):
            query_insert_configuracao = base_script_insert.format('UsaAzureStorageArquivosAnexos','true')
            cursor.execute(query_insert_configuracao)
            print(query_insert_configuracao)
        
        else:
            if(existe_UsaAzureStorageArquivosAnexos[0] =='false'):
                query_update_configuracao = base_script_update.format('true','UsaAzureStorageArquivosAnexos')
                cursor.execute(query_update_configuracao)
                print(query_update_configuracao)
        




        _con.commit()
        cursor.close()
# Out:
# cau-al.implanta.net.br Já configurado
# cau-am.implanta.net.br Já configurado
# cau-ap.implanta.net.br Já configurado
# cau-ba.implanta.net.br Já configurado
# cau-br.implanta.net.br Já configurado
# cau-ce.implanta.net.br Já configurado
# cau-df.implanta.net.br Já configurado
# cau-es.implanta.net.br Já configurado
# cau-go.implanta.net.br Já configurado
# cau-ma.implanta.net.br Já configurado
# cau-mg.implanta.net.br Já configurado
# cau-ms.implanta.net.br Já configurado
# cau-mt.implanta.net.br Já configurado
# cau-pa.implanta.net.br Já configurado
# cau-pb.implanta.net.br Já configurado
# cau-pe.implanta.net.br Já configurado
# cau-pi.implanta.net.br Já configurado
# cau-pr.implanta.net.br Já configurado
# cau-rn.implanta.net.br Já configurado
# cau-ro.implanta.net.br Já configurado
# cau-rr.implanta.net.br Já configurado
# cau-rs.implanta.net.br Já configurado
# cau-sc.implanta.net.br Já configurado
# cau-se.implanta.net.br Já configurado
# cau-to.implanta.net.br Já configurado
# cra-ac.implanta.net.br Já configurado
# cro-rs.implanta.net.br Já configurado
# configurando  crq-ba.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-ba\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-ba', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-ce.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-ce\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-ce', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-es.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-es\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-es', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-go.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-go\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-go', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-ma.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-ma\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-ma', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-ms.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-ms\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-ms', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-pa.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-pa\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-pa', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-pb.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-pb\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-pb', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-pe.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-pe\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-pe', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-pi.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-pi\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-pi', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-pr.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-pr\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-pr', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-rj.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-rj\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-rj', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-rn.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-rn\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-rn', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-rs.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-rs\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-rs', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-sc.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-sc\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-sc', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-se.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-se\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-se', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-sp.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-sp\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-sp', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crt-01.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crt-01\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crt-01', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crt-02.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crt-02\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crt-02', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crt-03.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crt-03\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crt-03', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crt-04.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crt-04\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crt-04', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crt-ba.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crt-ba\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crt-ba', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crt-es.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crt-es\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crt-es', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crt-mg.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crt-mg\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crt-mg', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crt-rj.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crt-rj\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crt-rj', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crt-rn.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crt-rn\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crt-rn', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crt-rs.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crt-rs\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crt-rs', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crt-sp.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crt-sp\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob01;AccountKey=PJIhpHc87NOvJgun39MNGH0sk/Rud+RCwigJ77LnQMkAowC3hOe5hKIGa0csKA83AZ3zHh6hkoDn6mqylTH02A==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crt-sp', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  confere-br.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\confere-br\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob02;AccountKey=4mYKld+m23dwKP82K6kERUpU9/zGnBjKy+kGijtFISmgkXOLVAOJtNDsQZjPTfMrcrRQdG/iIjOj5tIotsGyWQ==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'confere-br', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# core-al.implanta.net.br Já configurado
# core-am.implanta.net.br Já configurado
# core-ap.implanta.net.br Já configurado
# core-ba.implanta.net.br Já configurado
# core-ce.implanta.net.br Já configurado
# core-df.implanta.net.br Já configurado
# core-es.implanta.net.br Já configurado
# core-go.implanta.net.br Já configurado
# core-ma.implanta.net.br Já configurado
# core-mg.implanta.net.br Já configurado
# core-ms.implanta.net.br Já configurado
# core-mt.implanta.net.br Já configurado
# core-pa.implanta.net.br Já configurado
# core-pb.implanta.net.br Já configurado
# core-pe.implanta.net.br Já configurado
# core-pi.implanta.net.br Já configurado
# core-pr.implanta.net.br Já configurado
# core-rj.implanta.net.br Já configurado
# core-rn.implanta.net.br Já configurado
# core-ro.implanta.net.br Já configurado
# core-rs.implanta.net.br Já configurado
# core-sc.implanta.net.br Já configurado
# core-se.implanta.net.br Já configurado
# core-sp.implanta.net.br Já configurado
# core-to.implanta.net.br Já configurado
# coren-ac.implanta.net.br Já configurado
# coren-al.implanta.net.br Já configurado
# coren-ap.implanta.net.br Já configurado
# coren-ba.implanta.net.br Já configurado
# coren-ce.implanta.net.br Já configurado
# coren-df.implanta.net.br Já configurado
# coren-es.implanta.net.br Já configurado
# coren-ma.implanta.net.br Já configurado
# coren-mg.implanta.net.br Já configurado
# coren-ms.implanta.net.br Já configurado
# coren-pa.implanta.net.br Já configurado
# coren-pe.implanta.net.br Já configurado
# coren-pi.implanta.net.br Já configurado
# coren-pr.implanta.net.br Já configurado
# coren-rj.implanta.net.br Já configurado
# coren-rn.implanta.net.br Já configurado
# coren-ro.implanta.net.br Já configurado
# coren-rr.implanta.net.br Já configurado
# coren-rs.implanta.net.br Já configurado
# coren-sc.implanta.net.br Já configurado
# coren-sp.implanta.net.br Já configurado
# coren-to.implanta.net.br Já configurado
# crea-ac.implanta.net.br Já configurado
# crea-al.implanta.net.br Já configurado
# crea-am.implanta.net.br Já configurado
# crea-ap.implanta.net.br Já configurado
# crea-ba.implanta.net.br Já configurado
# crea-ce.implanta.net.br Já configurado
# crea-df.implanta.net.br Já configurado
# crea-es.implanta.net.br Já configurado
# crea-go.implanta.net.br Já configurado
# crea-mg.implanta.net.br Já configurado
# crea-ms.implanta.net.br Já configurado
# crea-mt.implanta.net.br Já configurado
# crea-pa.implanta.net.br Já configurado
# crea-pe.implanta.net.br Já configurado
# crea-pr.implanta.net.br Já configurado
# crea-rj.implanta.net.br Já configurado
# crea-rn.implanta.net.br Já configurado
# crea-ro.implanta.net.br Já configurado
# crea-rr.implanta.net.br Já configurado
# crea-rs.implanta.net.br Já configurado
# crea-sc.implanta.net.br Já configurado
# crea-se.implanta.net.br Já configurado
# crea-sp.implanta.net.br Já configurado
# crea-to.implanta.net.br Já configurado
# configurando  crefito-ba.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-ba\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-ba', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crefito-ce.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-ce\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-ce', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crefito-df.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-df\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-df', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crefito-es.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-es\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-es', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crefito-ma.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-ma\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-ma', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crefito-mg.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-mg\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-mg', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crefito-ms.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-ms\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-ms', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crefito-mt.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-mt\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-mt', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crefito-pa.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-pa\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-pa', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crefito-pe.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-pe\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-pe', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crefito-pi.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-pi\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-pi', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crefito-pr.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-pr\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-pr', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crefito-rj.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-rj\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-rj', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crefito-rs.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-rs\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-rs', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crefito-sc.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-sc\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-sc', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crefito-sp.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crefito-sp\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crefito-sp', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crf-ac.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crf-ac\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crf-ac', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crf-al.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crf-al\', 0);
# ...
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crp-se\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crp-se', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crp-sp.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crp-sp\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crp-sp', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crp-to.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crp-to\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crp-to', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  crq-al.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\crq-al\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'crq-al', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  oab-ac.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\oab-ac\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'oab-ac', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  oab-al.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\oab-al\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'oab-al', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  oab-am.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\oab-am\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'oab-am', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  oab-ap.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\oab-ap\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'oab-ap', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  oab-ce.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\oab-ce\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'oab-ce', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  oab-df.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\oab-df\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'oab-df', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  oab-ms.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\oab-ms\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'oab-ms', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  oab-pa.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\oab-pa\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'oab-pa', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  oab-pi.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\oab-pi\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'oab-pi', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  oab-rn.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\oab-rn\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'oab-rn', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  oab-rr.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\oab-rr\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'oab-rr', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  oab-rs.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\oab-rs\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'oab-rs', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'
# configurando  oab-se.implanta.net.br
# UPDATE C SET C.Valor ='500' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='QuantidadeDeArquivosMigradosPorExecucao'
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'CaminhoCacheLocalAzureStorageArquivosAnexos', 'D:\temp_blob_azure\oab-se\', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ConnectionStringAzureStorageArquivosAnexos', 'DefaultEndpointsProtocol=https;AccountName=improblob03;AccountKey=WEA4YzMZHaeDg0TBLXQje+EkZanSNVyPxKvmYKGQeVO/Blo9bsjlI4yjpI7DivAMuK6KPvoRBHq5MRZzqDdJEA==;EndpointSuffix=core.windows.net', 0);
# INSERT INTO Sistema.Configuracoes VALUES(NEWID(), '00000000-0000-0000-0000-000000000000', 'Global', 'ContainerAzureStorageArquivosAnexos', 'oab-se', 0);
# UPDATE C SET C.Valor ='true' FROM  Sistema.Configuracoes C WHERE C.Configuracao ='UsaAzureStorageArquivosAnexos'

# %% [markdown]
# ## Validação  das configuraçoes , devem existir 6 configuracoe

# %%
sql_query_Validation_configuracao = ("SELECT COUNT(1) FROM Sistema.Configuracoes AS C WHERE "
       "C.Configuracao IN ( "
       "'QuantidadeDeArquivosMigradosPorExecucao', 'CaminhoCacheLocalAzureStorageArquivosAnexos',"
       "'ConnectionStringAzureStorageArquivosAnexos', 'ContainerAzureStorageArquivosAnexos', "
       "'HorarioMigracaoArquivosAnexosParaAzureStorage', 'UsaAzureStorageArquivosAnexos') ")

# %%
for index , row in filter_categorias.iterrows():
    database = row["Cliente"]
    categoria = row["Categoria"]
    migracaoDiaria = row["MigracaoDiaria"]
    UtilizaAzure = row["UtilizaAzure"]
    
    storageAccount =  row["StorageAccount"]
    container =row["ContainerAzureStorageArquivosAnexos"]
    horarioMigracao =row["HorarioMigracaoArquivosAnexosParaAzureStorage"]
    connect_str_to_storage = row["ConnectionStringAzureStorageArquivosAnexos"]
    cLocalAzureStorageArquivosAnexos =row["CaminhoCacheLocalAzureStorageArquivosAnexos"]

    
    
    blob_service_client = BlobServiceClient.from_connection_string(connect_str_to_storage)
    existContainer = blob_service_client.get_container_client(container).exists()

    if(existContainer ==False):
        print('Container não configurado:',container)

    if(existContainer ==True):
        
        _con = get_conection(driver,server,database,username,password)
        cursor = _con.cursor()

        cursor.execute(sql_query_Validation_configuracao)

        validate = cursor.fetchone()
        if(validate[0] != 6):
            print(database, 'Com erro')


        _con.commit()
        cursor.close()
