# %% [markdown]
# ## Operador is

# %%
"Wesley" -is [int]
# Out:
# False

# %%
"Wesley" -is [string]
# Out:
# . {
# >> "Wesley" -is [string]
# >> }
# >>
# True

# %%
("31/12/2010").GetType()
# Out:
# IsPublic IsSerial Name                                     BaseType
# -------- -------- ----                                     --------
# True     True     String                                   System.Object

# %%
"31/12/2010" -as [datetime]
# Out:
# sexta-feira, 31 de dezembro de 2010 00:00:00

# %% [markdown]
# ## operadores de comparação
#
# em diversas linguagesns esse aqui são os comparadores padrao
#
#
#
#   > < == !=

# %% [markdown]
# <img src="data:image/png;base64,..." alt="">

# %% [markdown]
# ## no PW são esses os operadores

# %% [markdown]
# <img src="data:image/png;base64,..." alt="">

# %% [markdown]
# <img src="data:image/png;base64,..." alt="">

# %%
-eq -ne -lt -le -gt -ge

# %%
3 -lt 10
# Out:
# True

# %%
3 -le 3
# Out:
# True

# %%
3 -le 4
# Out:
# True

# %%
4 -le3
# Out:
# False

# %%
3 -gt5
# Out:
# False

# %%
88 -gt4
# Out:
# True

# %%
'Wesley' -eq 'wesley'
# Out:
# True

# %% [markdown]
# ## igualdade com Case Sensitive

# %%
'Wesley' -ceq 'wesley'
# Out:
# False

# %% [markdown]
# ## Mais de operadores

# %%
3  -eq 3
# Out:
# True

# %%
(3 -eq 3) -and  (10 -eq 9)
# Out:
# False

# %%
(3 -eq 3) -and  (10 -lt 9)
# Out:
# False

# %%
Test-Path .\Python
# Out:
# False

# %%
Test-Path D:\Wesley\VersionCode\BancoDados\PowerShell
# Out:
# True

# %%
if(Test-Path D:\Wesley\VersionCode\BancoDados\PowerShell){

        Write-Host "Diretorio Existe"

}
else {
    Write-Host "Diretorio Não Existe"
}
# Out:
# Diretorio Existe

# %%
if(!(Test-Path D:\Wesley\VersionCode\BancoDados\PowerShell)){
    
    Write-Host "Diretorio Não Existe"

}
else {
    Write-Host "Diretorio Existe"
}
# Out:
# Diretorio Existe
