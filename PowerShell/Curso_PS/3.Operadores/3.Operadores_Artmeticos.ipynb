# %% [markdown]
# <img src="data:image/png;base64,..." alt="">

# %%
(10 *20) +(4 *5)
# Out:
# 220

# %%
10 % 2 -eq 0
# Out:
# True

# %%
11 % 2 -eq 0
# Out:
# False

# %% [markdown]
# ## Sufixos de operadores de grandeza
#
# mb = megabytes
#
# gb = gigabytes<br>

# %%
1mb
# Out:
# 1048576

# %%
1gb
# Out:
# 1073741824
