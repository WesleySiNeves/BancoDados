# %% [markdown]
# \## gerenciando o ADDS
#
# \# Primeiramente precisamos importar o modulo do AD

# %%
##https://www.jorgebernhardt.com/how-to-install-powershell-active-directory-module/
Install-Module ActiveDirectory
# Out:
# PackageManagement\Install-Package : No match was found for the specified search criteria and module name
# 'ActiveDirectory'. Try Get-PSRepository to see all available registered module repositories.
# No C:\Program Files\WindowsPowerShell\Modules\PowerShellGet\1.0.0.1\PSModule.psm1:1809 caractere:21
# + ...          $null = PackageManagement\Install-Package @PSBoundParameters
# +                      ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     + CategoryInfo          : ObjectNotFound: (Microsoft.Power....InstallPackage:InstallPackage) [Install-Package], Ex
#    ception
#     + FullyQualifiedErrorId : NoMatchFoundForCriteria,Microsoft.PowerShell.PackageManagement.Cmdlets.InstallPackage

# %%
Import-Module ActiveDirectory
# Out:
# Import-Module : O m■dulo especificado 'ActiveDirectory' n■ foi carregado porque nenhum arquivo de m■dulo v■lido foi
# encontrado em nenhum diret■rio de m■dulo.
# No linha:2 caractere:1
# + Import-Module ActiveDirectory
# + ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     + CategoryInfo          : ResourceUnavailable: (ActiveDirectory:String) [Import-Module], FileNotFoundException
#     + FullyQualifiedErrorId : Modules_ModuleNotFound,Microsoft.PowerShell.Commands.ImportModuleCommand

# %%
Get-ChildItem AD:
# Out:
# Get-ChildItem : N■ ■ poss■vel localizar a unidade. N■ existe uma unidade com o nome 'AD'.
# No linha:2 caractere:1
# + Get-ChildItem AD:
# + ~~~~~~~~~~~~~~~~~
#     + CategoryInfo          : ObjectNotFound: (AD:String) [Get-ChildItem], DriveNotFoundException
#     + FullyQualifiedErrorId : DriveNotFound,Microsoft.PowerShell.Commands.GetChildItemCommand

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# \## Recuperar as diretrizes de senhas

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ## Verificar todos os computadores do Dominio

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# \## Verificar todos os usuarios do dominio

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# \## Criando uma nova organização no AD

# %% [markdown]
# ![](data:image/png;base64,...)
