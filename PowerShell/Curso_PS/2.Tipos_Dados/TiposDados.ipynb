# %% [markdown]
# ##Todos os tipos de dados erdam de Object

# %% [markdown]
# <img src="data:image/png;base64,..." alt="">

# %%
Get-Item D:\Wesley\VersionCode\BancoDados\PowerShell\teste.txt
# Out:
#     Diret■rio: D:\Wesley\VersionCode\BancoDados\PowerShell
#
#
# Mode                LastWriteTime         Length Name
# ----                -------------         ------ ----
# -a----       01/12/2020     07:52              9 teste.txt

# %% [markdown]
# ## Criando variaveis

# %%
$arquivo = Get-Item D:\Wesley\VersionCode\BancoDados\PowerShell\teste.txt

# %% [markdown]
# ## para acessar metodos e propriedades usamos o pipe '|'

# %%
$arquivo | Get-Member -MemberType Methods
# Out:
#    TypeName: System.IO.FileInfo
#
# Name                      MemberType Definition
# ----                      ---------- ----------
# AppendText                Method     System.IO.StreamWriter AppendText()
# CopyTo                    Method     System.IO.FileInfo CopyTo(string destFileName), System.IO.FileInfo CopyTo(strin...
# Create                    Method     System.IO.FileStream Create()
# CreateObjRef              Method     System.Runtime.Remoting.ObjRef CreateObjRef(type requestedType)
# CreateText                Method     System.IO.StreamWriter CreateText()
# Decrypt                   Method     void Decrypt()
# Delete                    Method     void Delete()
# Encrypt                   Method     void Encrypt()
# Equals                    Method     bool Equals(System.Object obj)
# GetAccessControl          Method     System.Security.AccessControl.FileSecurity GetAccessControl(), System.Security....
# GetHashCode               Method     int GetHashCode()
# ...

# %% [markdown]
# ## Propriedades

# %%
$arquivo | Get-Member -MemberType Properties
# Out:
#    TypeName: System.IO.FileInfo
#
# Name              MemberType     Definition
# ----              ----------     ----------
# LinkType          CodeProperty   System.String LinkType{get=GetLinkType;}
# Mode              CodeProperty   System.String Mode{get=Mode;}
# Target            CodeProperty   System.Collections.Generic.IEnumerable`1[[System.String, mscorlib, Version=4.0.0.0,...
# PSChildName       NoteProperty   string PSChildName=teste.txt
# PSDrive           NoteProperty   PSDriveInfo PSDrive=D
# PSIsContainer     NoteProperty   bool PSIsContainer=False
# PSParentPath      NoteProperty   string PSParentPath=Microsoft.PowerShell.Core\FileSystem::D:\Wesley\VersionCode\Ban...
# PSPath            NoteProperty   string PSPath=Microsoft.PowerShell.Core\FileSystem::D:\Wesley\VersionCode\BancoDado...
# PSProvider        NoteProperty   ProviderInfo PSProvider=Microsoft.PowerShell.Core\FileSystem
# Attributes        Property       System.IO.FileAttributes Attributes {get;set;}
# ...

# %%
$arquivo.Length
# Out:
# 9

# %% [markdown]
# ## Tipos de dados basicos

# %%
[int]
# Out:
# IsPublic IsSerial Name                                     BaseType
# -------- -------- ----                                     --------
# True     True     Int32                                    System.ValueType

# %%
[string]
# Out:
# IsPublic IsSerial Name                                     BaseType
# -------- -------- ----                                     --------
# True     True     String                                   System.Object

# %% [markdown]
# ## single no PW é o float no c#

# %%
[single]
# Out:
# IsPublic IsSerial Name                                     BaseType
# -------- -------- ----                                     --------
# True     True     Single                                   System.ValueType

# %%
(1).GetType()
# Out:
# IsPublic IsSerial Name                                     BaseType
# -------- -------- ----                                     --------
# True     True     Int32                                    System.ValueType

# %%
("1").GetType()
# Out:
# IsPublic IsSerial Name                                     BaseType
# -------- -------- ----                                     --------
# True     True     String                                   System.Object

# %%
(1.10).GetType()
# Out:
# IsPublic IsSerial Name                                     BaseType
# -------- -------- ----                                     --------
# True     True     Double                                   System.ValueType
