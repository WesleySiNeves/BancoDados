# %% [markdown]
# ## Caracteres de escape padrão de varias linguagens

# %% [markdown]
# <img src="data:image/png;base64,..." alt="">

# %%
Write-Host "wesley \nneves"
# Out:
# wesley \nneves

# %%
Write-Host "wesley `nneves"
# Out:
# wesley
# neves

# %%
Write-Host "wesley \tneves"
# Out:
# wesley \tneves

# %%
Write-Host "wesley `tneves"
# Out:
# wesley 	neves

# %%
Write-Host "wesley `vneves"
# Out:
# wesley neves

# %% [markdown]
# ## Scape aspas simples e duplas
