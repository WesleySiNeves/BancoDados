# %% [markdown]
# <img src="data:image/png;base64,..." alt="">

# %% [markdown]
# ## Comando para escrever o host

# %%
Write-Host

# %% [markdown]
# ## retorna as pastas dentro do diretorio

# %%
Get-ChildItem
# Out:
#     Diret■rio: D:\Wesley
#
#
# Mode                LastWriteTime         Length Name
# ----                -------------         ------ ----
# d-----       04/11/2019     18:00                2.Cursos TI
# d-----       17/07/2018     20:40                Arquivos
# d-----       28/09/2020     18:31                Azure
# d-----       22/09/2020     08:29                Consultoria
# d-----       14/09/2020     23:24                Cursos Alura
# d-----       14/09/2020     08:38                Cursos Oficiais Microsoft
# d-----       09/09/2020     09:15                datasetsGitHub
# d-----       21/09/2020     20:56                DSA
# d-----       14/11/2020     14:25                Extensoes Azure Sql
# d-----       30/08/2020     17:06                Ferramentas Banco Dados
# d-----       19/11/2020     20:41                karina
# d-----       28/11/2020     10:56                Pentaho
# d-----       23/11/2020     14:16                VersionCode
# ...

# %% [markdown]
# ## Alterar para outro diretorio

# %%
Set-Location D:\Wesley\VersionCode\BancoDados\Python

Get-ChildItem
# Out:
#     Diret■rio: D:\Wesley\VersionCode\BancoDados\Python
#
#
# Mode                LastWriteTime         Length Name
# ----                -------------         ------ ----
# d-----       26/11/2020     15:09                Docker
# -a----       29/11/2020     08:37           1770 findInstancesSqlServerOnPremisse.ipynb

# %% [markdown]
# # No powerShell .\ indica a pasta atual
