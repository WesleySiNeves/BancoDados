# %% [markdown]
# ![](data:image/png;base64,...)

# %%
# using assembly system.collections

$Matriz = @(1,2,3,4)

$ArraryList =  New-Object System.Collections.ArrayList

$ArraryList.AddRange(('a','b','c'))

$ArraryList.Add('d')

$ArraryList
# Out:
# 3
# a
# b
# c
# d

# %%
$ArraryList.AddRange(10..20)

$ArraryList.IndexOf('d')
# Out:
# 3

# %%
$ArraryList.LastIndexOf('d')
# Out:
# 3

# %% [markdown]
# \## indexação  invertida

# %%
$ArraryList[-1..-5]
# Out:
# 20
# 19
# 18
# 17
# 16

# %%
# using assembly system.collections

$Matriz = @(1,2,3,4)

$ArraryList =  New-Object System.Collections.ArrayList

$ArraryList.AddRange(('a','b','c'))

$ArraryList.Add('d')

$lista = New-Object System.Collections.Generic.List[string]
# Out:
# 3

# %%
$lista
