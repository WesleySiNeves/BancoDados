# %%
Get-Process
# Out:
# Handles  NPM(K)    PM(K)      WS(K)     CPU(s)     Id  SI ProcessName
# -------  ------    -----      -----     ------     --  -- -----------
#     566      33    35168      33928      11,39  11920   1 ApplicationFrameHost
#     322      17     4240      15844       4,97   4412   0 armsvc
#     159      27     2148       7272       3,22  25620   0 aspnet_state
#     246      12     2672       6036       5,17   8108   1 atieclxx
#     160       8     1660       2708       7,98   2156   0 atiesrxx
#     244      14    10936      18672       9,30  19448   0 audiodg
#     234      16    16916      25480       0,28   3676   1 azuredatastudio
#     432      49   106832      90072      26,61   6900   1 azuredatastudio
#     646      56   173028     139512      32,70   9716   1 azuredatastudio
#    1015      42   235148     233780     129,64  10324   1 azuredatastudio
#     353      20    13264      26292       2,69  20144   1 azuredatastudio
# ...

# %%
Get-Process chrome
# Out:
# Handles  NPM(K)    PM(K)      WS(K)     CPU(s)     Id  SI ProcessName
# -------  ------    -----      -----     ------     --  -- -----------
#     624      67    72672      81436   1.690,84    264   1 chrome
#     220      13    13336      12628      12,33   1368   1 chrome
#     237      16    18332      14268       1,30   3660   1 chrome
#    2294      89   274500     295408   2.747,23   4016   1 chrome
#     242      16    24160      39720       0,95   5492   1 chrome
#     274      17     7400      10928      66,44   6628   1 chrome
#     246      19    65164      74572     122,56   7916   1 chrome
#     242      18    56404      60280     103,45   8912   1 chrome
#     238      16    21392      16768       2,02   8972   1 chrome
#     336      20    34288      62692       4,13   9112   1 chrome
#     243      16    30072      37252      87,78   9172   1 chrome
#     420      37   185028     147384     729,89  10732   1 chrome
# ...

# %%
Get-Process  | Select-Object WS #Memoria Ram
# Out:
#        WS
#        --
#  34742272
#  16224256
#   7446528
#   6180864
#   2772992
#  19120128
#  26091520
#  91639808
# 141471744
# 245710848
#  26923008
# 138354688
#  78553088
#  15167488
#   8704000
#   6275072
#   7794688
#  51904512
#  83390464
#  12931072
#  14610432
# 302567424
#  40673280
#  11173888
#  76369920
#  61726720
#  17170432
#  64208896
#  38154240
# 148942848
#  29958144
#  64270336
#   4333568
# 129372160
#  76918784
#  80310272
#  22278144
#  62222336
# 212512768
#  72921088
#  78241792
# 252035072
#  51712000
#   9433088
#  13811712
#  45776896
#  45756416
#  12673024
#   5378048
#   5177344
#   7413760
#   7577600
#  12009472
#   7401472
#   5177344
#   4849664
#   5177344
#   6381568
#   5177344
#   7401472
#   6438912
#   9015296
#   7376896
#   7401472
#   8179712
#  14024704
#  83845120
# 181616640
#   2920448
#  11186176
#  19357696
#  16318464
#  30736384
#  13479936
#   9801728
#  52944896
#  35258368
#  62840832
# 167473152
#   2899968
#   6725632
# ...
