# %% [markdown]
# ## Instala os modulos do Azure
#
# <br>

# %%
#Set-ExecutionPolicy RemoteSigned

if ($PSVersionTable.PSEdition -eq 'Desktop' -and (Get-Module -Name AzureRM -ListAvailable)) {
    Write-Warning -Message ('Az module not installed. Having both the AzureRM and ' +
      'Az modules installed at the same time is not supported.')
} else {
    Install-Module -Name Az -AllowClobber -Scope CurrentUser -force
}
# Out:
# AVISO: A vers■ '2.2.2' do m■dulo 'Az.Accounts' est■ em uso no momento. Tente novamente a opera■■ depois de fechar os
# aplicativos.
# AVISO: A vers■ '1.1.1' do m■dulo 'Az.Advisor' est■ em uso no momento. Tente novamente a opera■■ depois de fechar os
# aplicativos.
# AVISO: A vers■ '2.0.1' do m■dulo 'Az.Aks' est■ em uso no momento. Tente novamente a opera■■ depois de fechar os
# aplicativos.
# AVISO: A vers■ '1.1.4' do m■dulo 'Az.AnalysisServices' est■ em uso no momento. Tente novamente a opera■■ depois de
# fechar os aplicativos.
# AVISO: A vers■ '2.2.0' do m■dulo 'Az.ApiManagement' est■ em uso no momento. Tente novamente a opera■■ depois de
# fechar os aplicativos.
# AVISO: A vers■ '1.0.0' do m■dulo 'Az.AppConfiguration' est■ em uso no momento. Tente novamente a opera■■ depois de
# fechar os aplicativos.
# AVISO: A vers■ '1.1.0' do m■dulo 'Az.ApplicationInsights' est■ em uso no momento. Tente novamente a opera■■ depois de
#  fechar os aplicativos.
# ...

# %% [markdown]
# ## Identificar se o modulo do Azure está instalado

# %%
Import-Module Az

# %%
Get-Module -Name Az  | select Name, Version
# Out:
# Name Version
# ---- -------
# Az   5.2.0

# %% [markdown]
# ## Conectar na Conta do Azure , vamos conectar pelo tenantId
#
#
#
# ![](data:image/png;base64,...)

# %% [markdown]
# ## Variaveis

# %%
$TenantID ='5d512ad1-5a13-466d-ac3e-8b4368dbc1b6' # Conta particular wesleynevesimplantainformat.onmicrosoft

# %%
Connect-AzAccount -Tenant $TenantID
# Out:
# AVISO: TenantId '5d512ad1-5a13-466d-ac3e-8b4368dbc1b6' contains more than one active subscription. First one will be
# selected for further use. To select another subscription, use Set-AzContext.
# Account                                 SubscriptionName                               TenantId
# -------                                 ----------------                               --------
# wesley.neves@implantainformatica.com.br Assinatura do Visual Studio Enterprise - MPN-2 5d512ad1-5a13-466d-ac3e-8b436...

# %%
Get-AzResourceGroup
# Out:
# Get-AzResourceGroup : Your Azure credentials have not been set up or have expired, please run Connect-AzAccount to set
# up your Azure credentials.
# No linha:2 caractere:1
# + Get-AzResourceGroup
# + ~~~~~~~~~~~~~~~~~~~
#     + CategoryInfo          : CloseError: (:) [Get-AzResourceGroup], ArgumentException
#     + FullyQualifiedErrorId : Microsoft.Azure.Commands.ResourceManager.Cmdlets.Implementation.GetAzureResourceGroupCmd
#    let

# %% [markdown]
# ## Crair um Resource Group

# %%
$ResourceName ='rg-dev'
$Location = 'eastus'

# %%
New-AzResourceGroup -Name $ResourceName -Location $Location
# Out:
# New-AzResourceGroup : Your Azure credentials have not been set up or have expired, please run Connect-AzAccount to set
# up your Azure credentials.
# No linha:2 caractere:1
# + New-AzResourceGroup -Name $ResourceName -Location $Location
# + ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     + CategoryInfo          : CloseError: (:) [New-AzResourceGroup], ArgumentException
#     + FullyQualifiedErrorId : Microsoft.Azure.Commands.ResourceManager.Cmdlets.Implementation.NewAzureResourceGroupCmd
#    let

# %%
New-AzResourceGroup -Name $ResourceName -Location $Location
# Out:
# New-AzResourceGroup : Your Azure credentials have not been set up or have expired, please run Connect-AzAccount to set
# up your Azure credentials.
# No linha:2 caractere:1
# + New-AzResourceGroup -Name $ResourceName -Location $Location
# + ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     + CategoryInfo          : CloseError: (:) [New-AzResourceGroup], ArgumentException
#     + FullyQualifiedErrorId : Microsoft.Azure.Commands.ResourceManager.Cmdlets.Implementation.NewAzureResourceGroupCmd
#    let

# %%
New-AzureRmSqlServer -ResourceGroupName "ResourceGroup01" -Location "Central US" -ServerName "server01" -ServerVersion "12.0" -SqlAdministratorCredentials (Get-Credential)
ResourceGroupName        : resourcegroup01
ServerName               : server01
Location                 : Central US
SqlAdministratorLogin    : adminLogin
SqlAdministratorPassword :
ServerVersion            : 12.0
Tags                     :
